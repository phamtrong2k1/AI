# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from tensorflow.keras.utils import to_categorical, load_img, img_to_array
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import numpy as np
from keras.utils import np_utils
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense,Flatten, Dropout, Conv2D, MaxPooling2D

# %%
train = ImageDataGenerator(rescale=1/255)
train_url = '/content/drive/MyDrive/AI/11_money/train'

validation = ImageDataGenerator(rescale=1/255)
validation_url = '/content/drive/MyDrive/AI/11_money/validation'

# %%
train_generator = ImageDataGenerator(rotation_range = 10,
                                     zoom_range = 0.1,
                                     height_shift_range = 0.1,
                                     width_shift_range = 0.1,
                                     brightness_range = (0.9,1.1))
train_dataset = train_generator.flow_from_directory(train_url,
                                                    target_size = (150,150),
                                                    batch_size = 128,
                                                    class_mode = 'categorical')
validation_dataset = validation.flow_from_directory(validation_url,
                                                       target_size = (150,150),
                                                       batch_size = 128,
                                                       class_mode = 'categorical')
# Out:
# Found 55 images belonging to 11 classes.
# Found 55 images belonging to 11 classes.

# %%
train_dataset.class_indices
# Out:
# {'0.2k': 0,
#  '0.5k': 1,
#  '100k': 2,
#  '10k': 3,
#  '1k': 4,
#  '200k': 5,
#  '20k': 6,
#  '2k': 7,
#  '500k': 8,
#  '50k': 9,
#  '5k': 10}

# %%
model = Sequential()
model.add(Conv2D(16,(3,3),activation = 'relu',padding='same',input_shape=(150,150,3)))
model.add(Conv2D(16,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(32,(3,3),activation = 'relu',padding='same'))
model.add(Conv2D(32,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation = 'relu',padding='same'))
model.add(Conv2D(64,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128,(3,3),activation = 'relu',padding='same'))
model.add(Conv2D(128,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(256,activation='relu',))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 150, 150, 16)      448
#
#  conv2d_33 (Conv2D)          (None, 150, 150, 16)      2320
#
#  max_pooling2d_16 (MaxPoolin  (None, 75, 75, 16)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 75, 75, 32)        4640
#
#  conv2d_35 (Conv2D)          (None, 75, 75, 32)        9248
#
#  max_pooling2d_17 (MaxPoolin  (None, 37, 37, 32)       0
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 37, 37, 64)        18496
#
#  conv2d_37 (Conv2D)          (None, 37, 37, 64)        36928
#
#  max_pooling2d_18 (MaxPoolin  (None, 18, 18, 64)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 18, 18, 128)       73856
#
#  conv2d_39 (Conv2D)          (None, 18, 18, 128)       147584
#
#  max_pooling2d_19 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 10368)             0
#
#  dense_8 (Dense)             (None, 256)               2654464
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 2,950,811
# Trainable params: 2,950,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
#opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer= Adam(), loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset,batch_size=12,epochs=100,verbose=1,validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 2.3913 - val_accuracy: 0.0909
# Epoch 2/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0701 - accuracy: 0.9818 - val_loss: 2.3894 - val_accuracy: 0.0909
# Epoch 3/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0841 - accuracy: 0.9455 - val_loss: 2.3883 - val_accuracy: 0.0909
# Epoch 4/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0740 - accuracy: 0.9818 - val_loss: 2.3872 - val_accuracy: 0.0909
# Epoch 5/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0374 - accuracy: 0.9818 - val_loss: 2.3866 - val_accuracy: 0.0909
# Epoch 6/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2987 - accuracy: 0.9455 - val_loss: 2.3891 - val_accuracy: 0.0909
# Epoch 7/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0718 - accuracy: 0.9636 - val_loss: 2.3929 - val_accuracy: 0.0909
# Epoch 8/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 2.3967 - val_accuracy: 0.0909
# Epoch 9/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1919 - accuracy: 0.9636 - val_loss: 2.3999 - val_accuracy: 0.0909
# Epoch 10/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0902 - accuracy: 0.9636 - val_loss: 2.3993 - val_accuracy: 0.0909
# Epoch 11/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2735 - accuracy: 0.9273 - val_loss: 2.3944 - val_accuracy: 0.0909
# Epoch 12/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0661 - accuracy: 0.9818 - val_loss: 2.3919 - val_accuracy: 0.1273
# Epoch 13/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1669 - accuracy: 0.9455 - val_loss: 2.3910 - val_accuracy: 0.1636
# Epoch 14/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1950 - accuracy: 0.9273 - val_loss: 2.3915 - val_accuracy: 0.1636
# Epoch 15/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1628 - accuracy: 0.9091 - val_loss: 2.3924 - val_accuracy: 0.1273
# Epoch 16/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0909 - accuracy: 0.9818 - val_loss: 2.3921 - val_accuracy: 0.0727
# Epoch 17/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1788 - accuracy: 0.9636 - val_loss: 2.3903 - val_accuracy: 0.0727
# Epoch 18/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 2.3893 - val_accuracy: 0.0909
# Epoch 19/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1259 - accuracy: 0.9455 - val_loss: 2.3887 - val_accuracy: 0.0909
# Epoch 20/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0625 - accuracy: 0.9636 - val_loss: 2.3879 - val_accuracy: 0.1091
# Epoch 21/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0919 - accuracy: 0.9636 - val_loss: 2.3882 - val_accuracy: 0.0909
# Epoch 22/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 2.3884 - val_accuracy: 0.0727
# Epoch 23/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0898 - accuracy: 0.9636 - val_loss: 2.3911 - val_accuracy: 0.1091
# Epoch 24/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 2.3941 - val_accuracy: 0.1455
# Epoch 25/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0533 - accuracy: 0.9818 - val_loss: 2.3975 - val_accuracy: 0.1455
# Epoch 26/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0326 - accuracy: 0.9818 - val_loss: 2.4008 - val_accuracy: 0.1455
# Epoch 27/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1774 - accuracy: 0.9455 - val_loss: 2.3997 - val_accuracy: 0.1636
# Epoch 28/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0380 - accuracy: 0.9818 - val_loss: 2.3976 - val_accuracy: 0.1273
# Epoch 29/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 2.3956 - val_accuracy: 0.0909
# Epoch 30/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 2.3944 - val_accuracy: 0.0909
# Epoch 31/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 2.3937 - val_accuracy: 0.0909
# Epoch 32/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 2.3933 - val_accuracy: 0.0909
# Epoch 33/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 2.3942 - val_accuracy: 0.0909
# Epoch 34/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 2.3964 - val_accuracy: 0.0909
# Epoch 35/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2349 - accuracy: 0.9273 - val_loss: 2.4024 - val_accuracy: 0.0909
# Epoch 36/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 2.4080 - val_accuracy: 0.0909
# Epoch 37/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1066 - accuracy: 0.9636 - val_loss: 2.3967 - val_accuracy: 0.0909
# Epoch 38/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0308 - accuracy: 0.9818 - val_loss: 2.3873 - val_accuracy: 0.0909
# Epoch 39/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 2.3807 - val_accuracy: 0.1273
# Epoch 40/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0430 - accuracy: 0.9818 - val_loss: 2.3808 - val_accuracy: 0.1636
# Epoch 41/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.3806 - val_accuracy: 0.1636
# Epoch 42/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1118 - accuracy: 0.9636 - val_loss: 2.3891 - val_accuracy: 0.1273
# Epoch 43/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 2.3965 - val_accuracy: 0.0909
# Epoch 44/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0696 - accuracy: 0.9818 - val_loss: 2.4030 - val_accuracy: 0.0909
# Epoch 45/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0358 - accuracy: 0.9818 - val_loss: 2.4085 - val_accuracy: 0.0909
# Epoch 46/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 2.4128 - val_accuracy: 0.0909
# Epoch 47/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 2.4147 - val_accuracy: 0.0909
# Epoch 48/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 2.4121 - val_accuracy: 0.0909
# Epoch 49/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0543 - accuracy: 0.9818 - val_loss: 2.4024 - val_accuracy: 0.0909
# Epoch 50/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0604 - accuracy: 0.9636 - val_loss: 2.3969 - val_accuracy: 0.0909
# Epoch 51/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0714 - accuracy: 0.9818 - val_loss: 2.3945 - val_accuracy: 0.0909
# Epoch 52/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 2.3940 - val_accuracy: 0.0909
# Epoch 53/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0451 - accuracy: 0.9818 - val_loss: 2.3945 - val_accuracy: 0.0909
# Epoch 54/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0614 - accuracy: 0.9636 - val_loss: 2.3912 - val_accuracy: 0.0909
# Epoch 55/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 2.3895 - val_accuracy: 0.0909
# Epoch 56/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0777 - accuracy: 0.9818 - val_loss: 2.3894 - val_accuracy: 0.0909
# Epoch 57/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0754 - accuracy: 0.9636 - val_loss: 2.3908 - val_accuracy: 0.0909
# Epoch 58/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 2.3921 - val_accuracy: 0.0909
# Epoch 59/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 2.3935 - val_accuracy: 0.0909
# Epoch 60/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.3950 - val_accuracy: 0.0909
# Epoch 61/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 2.3963 - val_accuracy: 0.0909
# Epoch 62/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.3973 - val_accuracy: 0.1455
# Epoch 63/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 2.3969 - val_accuracy: 0.1455
# Epoch 64/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 2.3963 - val_accuracy: 0.1455
# Epoch 65/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 2.3955 - val_accuracy: 0.1455
# Epoch 66/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0618 - accuracy: 0.9818 - val_loss: 2.3933 - val_accuracy: 0.1818
# Epoch 67/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0407 - accuracy: 0.9818 - val_loss: 2.3918 - val_accuracy: 0.1818
# Epoch 68/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.3903 - val_accuracy: 0.1818
# Epoch 69/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.3887 - val_accuracy: 0.1818
# Epoch 70/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.3874 - val_accuracy: 0.1818
# Epoch 71/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 2.3862 - val_accuracy: 0.1818
# Epoch 72/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 2.3871 - val_accuracy: 0.1818
# Epoch 73/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 2.3894 - val_accuracy: 0.1818
# Epoch 74/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0280 - accuracy: 0.9818 - val_loss: 2.3909 - val_accuracy: 0.1636
# Epoch 75/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 2.3931 - val_accuracy: 0.1636
# Epoch 76/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0433 - accuracy: 0.9818 - val_loss: 2.3966 - val_accuracy: 0.1636
# Epoch 77/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0645 - accuracy: 0.9636 - val_loss: 2.3968 - val_accuracy: 0.1818
# Epoch 78/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0525 - accuracy: 0.9818 - val_loss: 2.3962 - val_accuracy: 0.0909
# Epoch 79/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0592 - accuracy: 0.9636 - val_loss: 2.3901 - val_accuracy: 0.0909
# Epoch 80/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0685 - accuracy: 0.9636 - val_loss: 2.3897 - val_accuracy: 0.0909
# Epoch 81/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.3896 - val_accuracy: 0.0909
# Epoch 82/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1354 - accuracy: 0.9636 - val_loss: 2.3908 - val_accuracy: 0.0909
# Epoch 83/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0574 - accuracy: 0.9818 - val_loss: 2.3941 - val_accuracy: 0.0909
# Epoch 84/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0445 - accuracy: 0.9818 - val_loss: 2.3973 - val_accuracy: 0.1818
# Epoch 85/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.4005 - val_accuracy: 0.1636
# Epoch 86/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1215 - accuracy: 0.9636 - val_loss: 2.3903 - val_accuracy: 0.1636
# Epoch 87/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0482 - accuracy: 0.9818 - val_loss: 2.3782 - val_accuracy: 0.1818
# Epoch 88/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0650 - accuracy: 0.9818 - val_loss: 2.3725 - val_accuracy: 0.1818
# Epoch 89/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0246 - accuracy: 0.9818 - val_loss: 2.3707 - val_accuracy: 0.1818
# Epoch 90/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.1059 - accuracy: 0.9636 - val_loss: 2.3767 - val_accuracy: 0.1818
# Epoch 91/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0533 - accuracy: 0.9636 - val_loss: 2.3859 - val_accuracy: 0.1455
# Epoch 92/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0393 - accuracy: 0.9818 - val_loss: 2.3946 - val_accuracy: 0.1091
# Epoch 93/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2584 - accuracy: 0.8909 - val_loss: 2.3785 - val_accuracy: 0.1455
# Epoch 94/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0467 - accuracy: 0.9636 - val_loss: 2.3741 - val_accuracy: 0.0909
# Epoch 95/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2089 - accuracy: 0.9091 - val_loss: 2.3823 - val_accuracy: 0.0909
# Epoch 96/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0517 - accuracy: 0.9818 - val_loss: 2.3897 - val_accuracy: 0.0909
# Epoch 97/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2324 - accuracy: 0.9455 - val_loss: 2.3939 - val_accuracy: 0.0909
# Epoch 98/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.2446 - accuracy: 0.9091 - val_loss: 2.3975 - val_accuracy: 0.0909
# Epoch 99/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0410 - accuracy: 0.9818 - val_loss: 2.4005 - val_accuracy: 0.0909
# Epoch 100/100
# 1/1 [==============================] - 6s 6s/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 2.4021 - val_accuracy: 0.1273

# %%
model.save('/content/drive/MyDrive/AI/11_money/11_money.h5')

# %%
model_Money = load_model('/content/drive/MyDrive/AI/11_money/11_money.h5')

# %%
score=model.evaluate(validation_dataset,verbose=1)
print('Sai số: ',score[0])
print('Độ chính xác: ',score[1])
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 2.4021 - accuracy: 0.1273
# Sai số:  2.4020979404449463
# Độ chính xác:  0.12727272510528564

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.show()

# %%
img = load_img('/content/drive/MyDrive/AI/11_money/predict/20k_test.jpg',target_size=(150,150))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
Label = ['0.2k', '0.5k', '1k','2k','5k','10k','20k','50k','100k','200k','500k']
print('Dự đoán là: ',Label[int(np.argmax(model_Money.predict(img),axis=-1))])
# Out:
# Dự đoán là:  200k
